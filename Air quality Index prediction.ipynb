# %%
import pandas as pd

# %%
df=pd.read_csv("city_day.csv")
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %%
df.head(10)
# Out:
#         City        Date  PM2.5  PM10      NO    NO2     NOx  NH3      CO  \
# 0  Ahmedabad  2015-01-01    NaN   NaN    0.92  18.22   17.15  NaN    0.92
# 1  Ahmedabad  2015-01-02    NaN   NaN    0.97  15.69   16.46  NaN    0.97
# 2  Ahmedabad  2015-01-03    NaN   NaN   17.40  19.30   29.70  NaN   17.40
# 3  Ahmedabad  2015-01-04    NaN   NaN    1.70  18.48   17.97  NaN    1.70
# 4  Ahmedabad  2015-01-05    NaN   NaN   22.10  21.42   37.76  NaN   22.10
# 5  Ahmedabad  2015-01-06    NaN   NaN   45.41  38.48   81.50  NaN   45.41
# 6  Ahmedabad  2015-01-07    NaN   NaN  112.16  40.62  130.77  NaN  112.16
# 7  Ahmedabad  2015-01-08    NaN   NaN   80.87  36.74   96.75  NaN   80.87
# 8  Ahmedabad  2015-01-09    NaN   NaN   29.16  31.00   48.00  NaN   29.16
# 9  Ahmedabad  2015-01-10    NaN   NaN     NaN   7.04    0.00  NaN     NaN
#
#      SO2      O3  Benzene  Toluene  Xylene  AQI AQI_Bucket
# 0  27.64  133.36     0.00     0.02    0.00  NaN        NaN
# ...

# %%
df.tail(10)
# Out:
#                 City        Date  PM2.5    PM10    NO    NO2    NOx    NH3  \
# 29521  Visakhapatnam  2020-06-22  33.17  108.22  5.58  42.45  27.06  13.70
# 29522  Visakhapatnam  2020-06-23  25.40   83.38  2.76  34.09  19.92  13.13
# 29523  Visakhapatnam  2020-06-24  34.36   90.90  1.22  23.38  13.12  14.45
# 29524  Visakhapatnam  2020-06-25  13.45   58.54  2.30  21.60  13.09  12.27
# 29525  Visakhapatnam  2020-06-26   7.63   32.27  5.91  23.27  17.19  11.15
# 29526  Visakhapatnam  2020-06-27  15.02   50.94  7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38   74.09  3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91   65.73  3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64   49.97  4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00   66.00  0.40  26.85  14.05   5.20
#
#          CO    SO2     O3  Benzene  Toluene  Xylene    AQI    AQI_Bucket
# ...

# %%
df.columns
# Out:
# Index(['City', 'Date', 'PM2.5', 'PM10', 'NO', 'NO2', 'NOx', 'NH3', 'CO', 'SO2',
#        'O3', 'Benzene', 'Toluene', 'Xylene', 'AQI', 'AQI_Bucket'],
#       dtype='object')

# %%
df.shape
# Out:
# (29531, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29531 entries, 0 to 29530
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        29531 non-null  object
#  1   Date        29531 non-null  object
#  2   PM2.5       24933 non-null  float64
#  3   PM10        18391 non-null  float64
#  4   NO          25949 non-null  float64
#  5   NO2         25946 non-null  float64
#  6   NOx         25346 non-null  float64
#  7   NH3         19203 non-null  float64
#  8   CO          27472 non-null  float64
#  9   SO2         25677 non-null  float64
#  10  O3          25509 non-null  float64
#  11  Benzene     23908 non-null  float64
#  12  Toluene     21490 non-null  float64
#  13  Xylene      11422 non-null  float64
#  14  AQI         24850 non-null  float64
#  15  AQI_Bucket  24850 non-null  object
# dtypes: float64(13), object(3)
# memory usage: 3.6+ MB

# %%
df.AQI_Bucket=df.AQI_Bucket.fillna("Unknown")

# %%
df.isnull().sum()
# Out:
# City              0
# Date              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket        0
# dtype: int64

# %%
pmedian=df["PM2.5"].median()
df["PM2.5"].fillna(pmedian,inplace=True)

# %%
pmmedian=df["PM10"].median()
df["PM10"].fillna(pmmedian,inplace=True)

# %%
nmedian=df["NO"].mean()
df["NO"].fillna(nmedian,inplace=True)

# %%
nomedian=df["NO2"].mean()
df["NO2"].fillna(nomedian,inplace=True)

# %%
noxmedian=df["NOx"].mean()
df["NOx"].fillna(noxmedian,inplace=True)

# %%
nhmedian=df["NH3"].mean()
df["NH3"].fillna(nhmedian,inplace=True)

# %%
cmedian=df["CO"].median()
df["CO"].fillna(cmedian,inplace=True)

# %%
smedian=df["SO2"].median()
df["SO2"].fillna(smedian,inplace=True)

# %%
omedian=df["O3"].mean()
df["O3"].fillna(omedian,inplace=True)

# %%
bmedian=df["Benzene"].median()
df["Benzene"].fillna(bmedian,inplace=True)

# %%
tmedian=df["Toluene"].median()
df["Toluene"].fillna(tmedian,inplace=True)

# %%
xmedian=df["Xylene"].median()
df["Xylene"].fillna(xmedian,inplace=True)

# %%
amedian=df["AQI"].median()
df["AQI"].fillna(amedian,inplace=True)

# %%
amedian=df["AQI"].median()
df["AQI"].fillna(amedian,inplace=True)

# %%
df.isnull().sum()
# Out:
# City          0
# Date          0
# PM2.5         0
# PM10          0
# NO            0
# NO2           0
# NOx           0
# NH3           0
# CO            0
# SO2           0
# O3            0
# Benzene       0
# Toluene       0
# Xylene        0
# AQI           0
# AQI_Bucket    0
# dtype: int64

# %%
x=df[['PM2.5','PM10','NO','NO2','NOx','NH3','CO','SO2','O3','Benzene','Toluene','Xylene','AQI']]
x
# Out:
#        PM2.5   PM10     NO    NO2    NOx        NH3     CO    SO2      O3  \
# 0      48.57  95.68   0.92  18.22  17.15  23.483476   0.92  27.64  133.36
# 1      48.57  95.68   0.97  15.69  16.46  23.483476   0.97  24.55   34.06
# 2      48.57  95.68  17.40  19.30  29.70  23.483476  17.40  29.07   30.70
# 3      48.57  95.68   1.70  18.48  17.97  23.483476   1.70  18.59   36.08
# 4      48.57  95.68  22.10  21.42  37.76  23.483476  22.10  39.33   39.31
# ...      ...    ...    ...    ...    ...        ...    ...    ...     ...
# 29526  15.02  50.94   7.68  25.06  19.54  12.470000   0.47   8.55   23.30
# 29527  24.38  74.09   3.42  26.06  16.53  11.990000   0.52  12.72   30.14
# 29528  22.91  65.73   3.45  29.53  18.33  10.710000   0.48   8.42   30.96
# 29529  16.64  49.97   4.05  29.26  18.80  10.030000   0.52   9.84   28.30
# 29530  15.00  66.00   0.40  26.85  14.05   5.200000   0.59   2.10   17.05
#
#        Benzene  Toluene  Xylene    AQI
# 0         0.00     0.02    0.00  118.0
# ...

# %%
y=df.iloc[:,-1]
y
# Out:
# 0             Unknown
# 1             Unknown
# 2             Unknown
# 3             Unknown
# 4             Unknown
#              ...
# 29526            Good
# 29527    Satisfactory
# 29528    Satisfactory
# 29529    Satisfactory
# 29530            Good
# Name: AQI_Bucket, Length: 29531, dtype: object

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20)

# %%
xtrain.shape
# Out:
# (23624, 13)

# %%
xtest.shape
# Out:
# (5907, 13)

# %%
ytrain.shape
# Out:
# (23624,)

# %%
ytest.shape
# Out:
# (5907,)

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
model.predict(xtest)
# Out:
# array(['Unknown', 'Moderate', 'Moderate', ..., 'Satisfactory',
#        'Satisfactory', 'Satisfactory'], dtype=object)

# %%
model.score(xtest,ytest)
# Out:
# 0.9922126290841374
